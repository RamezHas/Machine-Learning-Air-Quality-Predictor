# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from stack_data import markers_from_ranges

# %%
df = pd.read_csv("cleaned_air_quality.csv")
df["timestamp"] = pd.to_datetime(df["timestamp"])
df.head()
# Out:
#             timestamp  temperature  humidity  pm25
# 0 2025-04-28 13:00:00     1.000000  0.000000    28
# 1 2025-04-28 13:00:00     0.877551  0.257732    28
# 2 2025-04-28 10:00:00     0.000000  1.000000    42

# %%
print("\nSummary Statistics:")
df.describe()
# Out:
# Summary Statistics:
#                  timestamp  temperature  humidity       pm25
# count                    3     3.000000  3.000000   3.000000
# mean   2025-04-28 12:00:00     0.625850  0.419244  32.666667
# min    2025-04-28 10:00:00     0.000000  0.000000  28.000000
# 25%    2025-04-28 11:30:00     0.438776  0.128866  28.000000
# 50%    2025-04-28 13:00:00     0.877551  0.257732  28.000000
# 75%    2025-04-28 13:00:00     0.938776  0.628866  35.000000
# max    2025-04-28 13:00:00     1.000000  1.000000  42.000000
# std                    NaN     0.545449  0.519196   8.082904

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df["pm25"], bins=30, kde=True ,color='purple')
plt.title("Distribution of PM2.5 Levels")
plt.xlabel("Timestamp")
plt.ylabel("PM2.5")
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df["timestamp"], df["pm25"],marker='o',linestyle='-',color='teal')
plt.title("PM2.5 over Time")
plt.xlabel("Date")
plt.ylabel("PM2.5")
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x=df["pm25"],color='orange')
plt.title("PM2.5 Boxplot(Outlier Detection")
plt.xlabel("PM2.5")
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 5))
sns.scatterplot(data=df, y="pm25", x="temperature", color="blue", ax=axes[0])
axes[0].set_title("PM2.5 vs Temperature")
axes[0].set_xlabel("Normalized Temperature")
axes[0].set_ylabel("PM2.5")
sns.scatterplot(data=df,x="humidity",y="pm25",color="green",ax=axes[1])
axes[1].set_title("PM2.5 vs. Humidity")
axes[1].set_xlabel("Normalized Humidity")
axes[1].set_ylabel("PM2.5")
plt.tight_layout()
plt.show()
